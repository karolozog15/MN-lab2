# %% [markdown]
# # <center>Laboratorium 2<br>Metody Numeryczne<br>Karol Ożóg<br>Nr albumu 419388<br>Automatyka i Robotyka<br>WEAIiIB<br>2. rok, CWL gr. 6</center>

# %% [markdown]
# Biblioteki niezbędne do wykonania zadania:

# %%
import main
import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ***Zadanie 1.***
# Zdefiniuj w notatniku funkcję $f(x)= x^{3} - 3x$ i sporządź jej wykres dla argumentów z przedziału:
# 1. $x\in<-1,1>$
# 2. $x\in<-5,5>$
# 3. $x\in<0,5>$
#
# ***Wskazówki***
# Jako argumentu funkcji można użyć numpy array.
#
# Do wizualizacji wyników w Pythonie używa się pakietu [Matplotlib](https://matplotlib.org/). Działanie tego pakietu prezentuje przykład:

# %%
x = np.linspace(-10,10)
# inicjalizacja wektora f(x) = sin(x)
y = np.sin(x)
plt.plot(x, y, label ='sin(x)')
plt.show()

# %% [markdown]
# Wspierając się dokumentacją [Matplotlib](https://matplotlib.org/) dodaj do wykresu etykiety osi, tytuł, grid i legendę.

# %%
f=lambda x: x**3-3*x

x=np.linspace(-1,1)
y=f(x)
plt.figure()
plt.plot(x,y,label='x dla <-1,1>')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wykres dla x z przedziału <-1,1>")
plt.legend()
plt.grid()

x=np.linspace(-5,5)
y=f(x)
plt.figure()
plt.plot(x,y,label='x dla <-5,5>')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wykres dla x z przedziału <-5,5>")
plt.legend()
plt.grid()

x=np.linspace(0,5)
y=f(x)
plt.figure()
plt.plot(x,y,label='x dla <0,5>')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Wykres dla x z przedziału <0,5>")
plt.legend()
plt.grid()

# %% [markdown]
# ***Komentarz do zadania 1.***
#
#
# Zadanie polegało na narysowaniu wykresów zadanej funkcji dla trzech różnych dziedzin. W tym celu najpierw przy pomocy funkcji linspace tworzymy wektor o zadanych granicach, następnie wykorzystujemy utworzoną funkcję f do wyznaczenia wartości y=f(x). Komendą $plt.figure()$ tworzymy ramkę obrazu. Do funkcji $plt.plot()$ podajemy wektory x i y otrzymane poprzednio. Możemy następnie modyfikować wykresy dodając tytuł, opisy osi, legendę, oraz grid. Dzięki bibliotece matplotlib tworzenie wykresów i modyfikowanie wykresów jest proste i intuicyjne.

# %% [markdown]
# ***Zadanie 2.***
# Dla funkcji z zadania pierwszego używając wektora $x \in <-10,10>$ wyrysuj wykres dla argumentów:
# 1. $x\in<-1,1>$
# 2. $x\in<-10,-1>$
# 3. $x\in<1,10>$
#
# Używając do tego funkcji: [ylim](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.ylim.html), [xlim](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.xlim.html), [axis](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.axis.html)

# %%
x = np.linspace(-10,10)

y =f(x)
plt.figure()
plt.plot(x, y)
plt.xlim(-1,1)
plt.ylim(-5,5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Funkcja dla przedziału x <-1,1>')
plt.show()

plt.figure()
plt.plot(x, y)
plt.xlim(-10,-1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Funkcja dla przedziału x <-10,1>')
plt.show()

plt.figure()
plt.plot(x, y)
plt.xlim(1,10)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Funkcja dla przedziału x <1,10>')
plt.show()

# %% [markdown]
# ***Komentarz do zadania 2***
#
# Możemy zmieniać zakres osi x oraz y przez funkcję $plt.xlim()$ oraz $plt.ylim()$ podając granicę jako argumenty funkcji. W tym zadaniu widzimy, na 1. rysunku, że wykresy są tworzone  przez interpolację liniową między punktami z tablic x i y.

# %% [markdown]
# ***Zadanie 3.***
# Oblicz ilość ciepła, które wydzieli się podczas hamowania jeżeli opisuje je zależność:
#
# $Q = \cfrac{mv^2}{2}$
#
# jeżeli $m = 2500g$, $v = 60km/h$, wypisz wynik oraz podaj w kilokaloriach i dżulach. Wykreśl wykresy które zobrazują zmianę ilości ciepła w procesie hamowania dla ciała o masie $3000g$ i prędkości $v\in<200,0>km/h$, przedstawiając ciepło hamowania na pierwszym w skali liniowej na drugim w skali logarytmicznej.
#
# ***Wsakzówka:*** Do stworzenia wykresów z osią logarytmiczną skorzystaj z funkcji: [semilogy](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.semilogy.html), [xlim](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.xlim.html?highlight=xlim#matplotlib.pyplot.xlim) i [figure](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html?highlight=figure#matplotlib.pyplot.figure) z pakietu *Matplotlib*.

# %%
m=2500
v=60
Q=np.round(0.5*(m/1000)*(v/3.6)**2,2)
print(Q,"J, =", np.round(Q/4184,4),"kcal")

m=3000
v=np.linspace(200,0)

Q=0.5*(m/1000)*(v/3.6)**2

plt.figure()
plt.plot(v,Q)
plt.xlabel("v [km/h]")
plt.ylabel("Q [J] ")
plt.title("Ciepło hamowania skala liniowa")

plt.figure()
plt.semilogy()
plt.plot(v,Q)
plt.xlabel("v [km/h]")
plt.ylabel("Q [J] ")
plt.title("Ciepło hamowania skala logarytmiczna")
# Out:
# 347.22 J, = 0.083 kcal
# Text(0.5, 1.0, 'Ciepło hamowania skala logarytmiczna')

# %% [markdown]
# ***Komnetarz do zad. 3,***
#
# W tym zadaniu najpierw wyznaczyliśmy szukaną wartość ciepła w dżulach oraz w kilokaloriach. Następnie dla zadanych wartości narysowaliśmy dwa wykresy zmiany ilości ciepła w procesie hamowania, przedstawiając ciepło raz na skali liniowej a drugi raz, używając funkcji $plt.semligy$ na skali logarytmicznej

# %% [markdown]
# ***Zadanie 4.***
# Częstą praktyką szczególnie w dziedzinie analizy danych, statystyce, uczeniu maszynowym, itp. jest tworzenie na podstawie biblioteki [Matplotlib](https://matplotlib.org/) własnych szablonów wykresów stworzonych na podstawie funkcji. Najprostszy przykład to przeładowanie funkcji plot tak by wykres miał czerwony kolor:

# %%
def my_plot(x,y,xlabel,ylabel,title,label):
    if x.shape != y.shape or  min(x.shape)==0:
        return None
    fig, ax = plt.subplots()
    ax.plot(x, y, 'r', label=label)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.legend()
    return fig

x = np.linspace(-10,10)
# inicjalizacja wektora f(x) = sin(x)
y = np.sin(x)
my_plot(x,y,'x','y','Funkcja sin', 'sin(x)')
# Out:
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# Zaimplementuj funkcję *compare_plot* tak, aby na jednym wykresie zostały narysowane dwie serie danych za pomocą metody [plot](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot).
#
# - Pierwsza seria powinna być rysowana kolorem **niebieskim** z grubością linii równą `4`.
# - Druga seria powinna być rysowana kolorem **czerwonym** z grubością linii równą `2`.
#
# Domyślnie wykres powinien zawierać **legendę**.
# Dodatkowo użytkownik powinien mieć możliwość ustawienia następujących parametrów:
# - x1 - wektor wartości osi x dla pierwszego wykresu,
# - y1 - wektor wartości osi y dla pierwszego wykresu,
# - x2 - wektor wartości osi x dla drugiego wykresu,
# - y2 - wektor wartości osi x dla drugiego wykresu,
# - xlabel - opis osi x,
# - ylabel - opis osi y,
# - title - tytuł wykresu ,
# - label1 - nazwa serii z pierwszego wykresu,
# - label2 - nazwa serii z drugiego wykresu.
#
# Jeżeli nie da się wyrysować danych należy zwrócić wartość None.

# %%
def compare_plot(x1,y1,x2,y2,xlabel,ylabel,title,label1,label2):
    if x1.shape != y1.shape or  min(x1.shape)==0:
        return None
    if x2.shape != y2.shape or  min(x2.shape)==0:
        return None
    fig, ax = plt.subplots()
    ax.plot(x1, y1, 'r', label=label1,linewidth=4.0)
    ax.plot(x2, y2, 'b', label=label2,linewidth=2.0)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.legend()
    return fig

# %% [markdown]
# ***Komentarz do zadania 4.***
#
# W tym zadaniu utworzono funkcję która rysuje dwa wykresy na jednej ramce. Funkcja najpierw sprawdza czy wymiary wektorów i y są takie same oraz czy są różne od 0. Jeżeli funkcja nie spełnia tych warunków to zwraca None. Następnie tworzymy figure i osie do ktorych następnie przypisujemy dane wektory, opisujemy funkcje i opisujemy osie. Matplotlib pozwala w prosty sposób zmieniać grubość lini, kolor i innne parametry wykresu.

# %% [markdown]
# ***Zadanie 5***
# Za pomocą funkcji *compare\_plot* rozwiąż graficznie równanie: $f(x) = g(x)$, gdzie:
# $f(x) = x+2$
# $g(x) = x^2 -2sin(x) + 3$

# %%
x1=np.linspace(-10,10)
x2=np.linspace(-10,10)
y1=x1+2
y2=x2**2-2*np.sin(x2)+3
compare_plot(x1,y1,x2,y2,'x','y','Graficzne rozwiązanie równania','f(x)','g(x)')

# %% [markdown]
# ***Komentarz do zad. 5***
# W tym zadaniu sprawdzamy działanie utworzonej w zad. 4 funkcji. Tworzymy najpierw listę $x$ - dziedinę naszych funkcji. Następnie wyznaczamy $y_1$, oraz $y_2$ jako listy odpowiadających wartości funkcji f(x), oraz g(x). Następnie uruchamiamy funkcję  ustawiając jako argumenty wyznaczone listy, oraz odpowiednie parametry w funkcji jak tytuł, czy nazwy osi. Na otrzymanym wykresie widać, że funkcja prawidłowo spełnia swoje zadanie.

# %% [markdown]
# ***Zadanie 6.***
# Innym przydatnym sposobem prezentowania wykresów jest [subplot](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.subplot.html), czyli wyrysowanie obok siebie kilku wykresów. Zaimplementuj funkcję parallel_plot tak by obok siebie wyrysowane zostały dwa standardowe ploty i użytkownik mógł podać parametry:
# - x1 - wektor wartości osi x dla pierwszego wykresu,
# - y1 - wektor wartości osi y dla pierwszego wykresu,
# - x2 - wektor wartości osi x dla drugiego wykresu,
# - y2 - wektor wartości osi x dla drugiego wykresu,
# - x1label - opis osi x dla pierwszego wykresu,
# - y1label - opis osi y dla pierwszego wykresu,
# - x2label - opis osi x dla drugiego wykresu,
# - y2label - opis osi y dla drugiego wykresu,
# - title - tytuł wykresu,
# - orientation - parametr przyjmujący wartość '-' jeżeli subplot ma posiadać dwa wiersze albo '|' jeżeli ma posiadać dwie kolumny.
#
# Jeżeli nie da się wyrysować danych należy zwrócić wartość None.

# %%
def parallel_plot(x1,y1,x2,y2,x1label,y1label,x2label,y2label,title,orientation):
    if x1.shape != y1.shape or  min(x1.shape)==0:
        return None
    if x2.shape != y2.shape or  min(x2.shape)==0:
        return None
    if x1.shape != x2.shape:  
        return None
    if orientation not in ["-", "|"]:
        return None
    
    if orientation == "|":  
        fig, (ax1, ax2) = plt.subplots(1, 2)
    else:  
        fig, (ax1, ax2) = plt.subplots(2, 1)
    
    ax1.plot(x1, y1) 
    ax1.set(xlabel=x1label, ylabel=y1label, title=title)

    ax2.plot(x2, y2)
    ax2.set(xlabel=x2label, ylabel=y2label, title=title)

    
    return fig

# %% [markdown]
# ***Komentaarz do zad. 6***
#
# Zadanie to polegało na implementacji funkcji któa rysuję dwa wykresy, w zależności od parametru orientation w dwóch wierszach lub w dwóch kolumnach. W Matplotlib wykorzystuje się do tego funkcję plt.subplots(a,b), która tworzy w zależności od parametrów a-wierszy i b-kolumn. W  funkcji najpierw sprawdzamy czy wektory są odpowiedniej wielkości i czy x-owe są różne od 0. Następnie sprawdzamy czy wybrany odpowiedni znak orientacji, po czym w zależności od tego znaku wybieramy czy wykres ma byc kolumnowy czy wierszowy. Następnie rysujemy w każdym oknie zadane wykresy jak  w poprzednich zadaniach. Jest to wygodne narzędzie do porównywania dwóch wykresów między sobą na jednej ramce.

# %% [markdown]
# ***Zadanie 7.***
# Skorzystaj z funkcji *parallel_plot* i utwórz dwa wykresy:
# - na pierwszym przedstaw [spiralę logarytmiczną](https://pl.wikipedia.org/wiki/Spirala_logarytmiczna) w szerokim zakresie wartości,
# - na drugim zaprezentuj jej przebieg w pobliżu zera.

# %%
phi=np.linspace(-100,100,1000)
r=10*np.exp(0.1*phi)
x=r*np.cos(phi)
y=r*np.sin(phi)

phi2=np.linspace(-10,10,1000)
r2=10*np.exp(0.1*phi2)
x2=r2*np.cos(phi2)
y2=r2*np.sin(phi2)
parallel_plot(x,y,x2,y2,"x","y",'x','y','spirala','|')

# %% [markdown]
# ***Komentarz do zad. 7***
#
# Zadanie to polegało na wykorzystaniu zdefiniowanej w zad. 6 funkcji do przedstawienia spirali logarytmicznej. Najpierw definiujemy spirale dla dwóch zakresów jeden szeroki, a drugi wąski. Następnie definiujemy wektory x i y dla obu zakresów i uruchamiamy utworzoną w zad. 6 funkcję wykrozystując dane z zad. 7. Zadanie to pokazuje jak dobrym narzędziem do porównywania wykresów jest matplotlib.

# %% [markdown]
# ***Zadanie 8.***
# Zaimplementuj funkcję *log\_plot* która będzie tworzyć wykres w skalach logaritmicznych. Skale logarytmiczne mają być ustawione zgodnie z parameterem *log\_axis* gdzie wartość:
# - 'x' oznacza skale logarytmiczną na osi x,
# - 'y' oznacza skale logarytmiczną na osi y,
# - 'xy' oznacza skale logarytmiczną na obu osiach.
#
# Dodatkowo użytkownik ma mieć możliwość ustawienia parametrów:
# - x - wektor wartości osi x,
# - y - wektor wartości osi y,
# - xlabel - opis osi x,
# - ylabel - opis osi y,
# - title - tytuł wykresu.

# %%
def log_plot(x,y,xlabel,ylabel,title,logaxis):
    if x.shape != y.shape or  min(x.shape)==0:
        return None

    fig, ax = plt.subplots()
    ax.plot(x, y)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    if logaxis == "x":
        ax.set_xscale('log', base=10)
    elif logaxis == "y":
        ax.set_yscale('log', base=10)
    elif logaxis == "xy":
        ax.set_xscale('log', base=10)
        ax.set_yscale('log', base=10)

    return fig

# %% [markdown]
# ***Komentarz do zad. 8***
#
# Zadanie to polegało na implementacji funkcji do rysowania wykresu, w której przy doborze parametru log_axis można zmienić oś x, y lub obie na osie logarytmiczne. Do wykoania tej funkcji przydatna była set_xscale() oraz set_yscale() które po wprowadzeniu parametrów ('log',base=10), zamieniają oś x lub y na oś logarytmiczną o podstawie 10.

# %% [markdown]
# **Zadanie 9.**
# Wykorzystaj funkcję *log_plot*, aby ponownie zilustrować wyniki z Zadania 3.
# Przedstaw na wykresach różne warianty funkcji opisującej ilość ciepła podczas hamowania, korzystając z logarytmicznych skal osi (`'x'`, `'y'`, `'xy'`).

# %%
m=3000
v=np.linspace(200,0)

Q=0.5*(m/1000)*(v/3.6)**2

log_plot(v,Q,"v [km/h]","Q","cieplo",'x')

log_plot(v,Q,"v [km/h]","Q [J]","cieplo",'y')
log_plot(v,Q,"v [km/h]","Q [J]","cieplo",'xy')

# %% [markdown]
# ***Komentarz do zad. 9***
#
# Zadanie to polegało na wykorzystaniu zaimplementowanej w zad. 8 funkcji do reprezentacji funkcji z zad.3 w różnych skalach. W tym celu wykorzystano utworzoną poprzednio funkcję z użyciem trzech różnych parametrów: x- dla logarytmicznej skali x, y - dla logarytmicznej skali y, xy - dla logarytmicznych skal x oraz y. Dzięki temu można zaobserowwać jak skala logarytmiczna ma wpływ na prezentacje wyników.

# %% [markdown]
# **Zadanie 10.**
# Skorzystaj z funkcji *semilogx*, aby narysować wykres funkcji
# $$
# f(x) = \cos\bigl(2\pi x\bigr)
# $$
# w zakresie od co najmniej $-10^2$ do $10^0$.
#
# Do wygenerowania wartości funkcji użyj trzech różnych kroków:
# - pierwszy krok około `0.02`,
# - dwa pozostałe nieznacznie większe.
#
# ***Wartości wygeneruj przy pomocy *np.arange*.***
#
# Narysuj wykresy według schematu:
# - węzły (punkty, w których obliczono wartości funkcji) oznacz kropkami,
# - połącz je liniami przerywanymi.
#
# Zaobserwuj, jak zmienia się kształt wykresu przy zwiększaniu kroku.
# Dla porównania przygotuj również wykres bez zastosowania skali logarytmicznej.
#
# Całość umieść w układzie siatki `2x2` przy użyciu *subplot*.
# Nie zapomnij o dodaniu tytułów osi oraz poszczególnych wykresów.

# %%
x1=x = np.arange(-100, 1, 0.02)

x2=x = np.arange(-100, 1, 0.04)

x3=x = np.arange(-100, 1, 0.06)

plt.subplot(2,2,1)
plt.semilogx(x1,np.cos(2*np.pi*x1),'o--')
plt.title('krok 0.02')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(2,2,2)
plt.semilogx(x2,np.cos(2*np.pi*x2),'o--')
plt.title('krok 0.04')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(2,2,3)
plt.semilogx(x3,np.cos(2*np.pi*x3),'o--')
plt.title('krok 0.06')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ***Komentarz do zad.10***
#
# Do utworzenia tablicy o danych granicach i wybranym kroku wykorzystujemy funkcje np.arrange(). Następnie tworzymy siatkę 2x2 przez funkcję plt.subplot(). Następnie przy użyciu funkcji plt.semligx(), rysujemy zadane funkcje dla różnych kroków. Poprzez ustawienie parametrów "--o" w łatwy sposób zmieniamy format wykresu na kropki na danych i przerywane kreski między nimi. Dzięki prezentacji wykresów w jednej siatce 2x2 w łatwy sposób możemy porównać wpływ kroku na wyglą funkcji.

# %% [markdown]
# ***Podsumowanie***
#
# Na laboratorium nauczyliśmy się wykorzystywać bibliotkę Matplotlib do rysowania wykresów w Python. Nauczyliśmy się reprezentować funkcje w różny sposób m.in. pare wykresów na jednym wykresie, wykresy obok siebie, różne skale: liniowe, logarytmiczne. Opanowaliśmy również tworzenie funkcji automatyzujących proces tworzenia wykresów, co znacznie ułatwia analizę danych. Poznaliśmy Matplotlib jako wygodne i intuicyjnym narzędzie do reprezentacji i ogólnej analizy danych.

# %% [markdown]
# Materiały uzupełniające:
# - [Scipy Lecture Notes](http://www.scipy-lectures.org/index.html)
# - [NumPy for Matlab users](https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html#numpy-for-matlab-users)
# - [Python Tutorial - W3Schools](https://www.w3schools.com/python/default.asp)
# - [NumPy](https://www.numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Anaconda](https://www.anaconda.com/)
# - [Learn Python for Data Science](https://www.datacamp.com/learn-python-with-anaconda?utm_source=Anaconda_download&utm_campaign=datacamp_training&utm_medium=banner)
# - [Learn Python](https://www.learnpython.org/)
# - [Wujek Google](https://google.pl) i [Ciocia Wikipedia](https://pl.wikipedia.org/wiki/Wikipedia:Strona_g%C5%82%C3%B3wna)
